# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a51176/doc-1/blob/main/2403a51176.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1 – Fixing a Syntax Error in Conditional Statement

# %%
a = 10
if a == 10:
    print("Equal")
# Out:
# Equal

# %% [markdown]
# explanation:The if condition uses = instead of ==. In Python, == is used to compare values. Replacing = with == fixes the syntax error

# %% [markdown]
# Task 2 – Correcting an Off-By-One Error in Loop

# %%
def sum_upto(n):
    total = 0
    for i in range(1, n + 1):
        total += i
    return total
print(sum_upto(5))
# Out:
# 15

# %% [markdown]
# Explanation:The loop uses range(1, n), which excludes n. To include n in the sum, change it to range(1, n+1).

# %% [markdown]
# Task 3 – Handling an AttributeError in a Class

# %%
class User:
    def __init__(self, name):
        self.name = name

    def getName(self):
        return self.name

u = User("Alice")
print(u.getName())
# Out:
# Alice

# %% [markdown]
# Explanation:The code tries to call a method getName() which is not defined in the class. Adding the missing method fixes the error.

# %% [markdown]
# Task 4 – Fixing Method Definition in a Class

# %%
class Car:
    def start(self):
        print("Car started")

mycar = Car()
mycar.start()
# Out:
# Car started

# %% [markdown]
# Explanation:The class method is missing self as a parameter. Adding self allows the method to be called using an object.

# %% [markdown]
# Task 5 – Correcting Logical Errors in a Grading System

# %%
def grade_student(score):
    if score >= 70:
        return "A"
    elif score >= 40:
        return "B"
    else:
        return "C"
print(grade_student(85))
# Out:
# A

# %% [markdown]
# Explanation:The grading logic is reversed—low scores are getting high grades. Fix the conditions so higher scores get better grades.
